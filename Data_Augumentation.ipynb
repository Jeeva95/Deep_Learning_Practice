# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: failed to access '/root/.kaggle/': Not a directory

# %%
# !kaggle datasets download -d sshikamaru/fruit-recognition
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sshikamaru/fruit-recognition
# License(s): other
# ...
# 100% 102M/102M [00:01<00:00, 85.2MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/fruit-recognition.zip")
zip_ref.extractall("/content")
zip_ref.close()

# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img("/content/test/test/0000.jpg", target_size = (200, 200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
datagen = ImageDataGenerator(
    rotation_range = 0.2,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,
    brightness_range = None,
    zoom_range = 0.2
)

# %%
img = image.img_to_array(img)

# %%
input_batch = img.reshape(1, 200, 200, 3)

# %%
import os

os.makedirs("/content/fruit-recognition", exist_ok=True)

# %%
i = 0
for output in datagen.flow(input_batch, batch_size = 1, save_to_dir = "/content/fruit-recognition") :
  i += 1
  if i == 10 :
    break

# %%
img = image.load_img("/content/fruit-recognition/_0_2738.png", target_size = (200, 200))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
