# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.applications import VGG16

# %%
model = VGG16(weights = "imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
from tensorflow.keras.preprocessing import image

# %%
img_path = "/content/Dog1.jfif"
img = image.load_img(img_path, target_size = (224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import numpy as np

# %%
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis = 0)

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
img_array = preprocess_input(img_array)

# %%
predictions = model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions

# %%
decode_predictions(predictions, top = 5)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n02112018', 'Pomeranian', np.float32(0.9027339)),
#   ('n02086079', 'Pekinese', np.float32(0.038393073)),
#   ('n02112350', 'keeshond', np.float32(0.01297795)),
#   ('n02111889', 'Samoyed', np.float32(0.008546651)),
#   ('n02112137', 'chow', np.float32(0.008314272))]]
